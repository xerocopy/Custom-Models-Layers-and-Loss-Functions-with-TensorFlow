# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])


print(model.summary())
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 128)          1152        input_3[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 128)          16512       dense_6[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 64)           8256        dense_7[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_7[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_8[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 1ms/sample - loss: 244.1557 - y1_output_loss: 108.7441 - y2_output_loss: 133.3878 - y1_output_root_mean_squared_error: 10.4690 - y2_output_root_mean_squared_error: 11.5998 - val_loss: 83.6174 - val_y1_output_loss: 22.6089 - val_y2_output_loss: 59.6865 - val_y1_output_root_mean_squared_error: 4.8136 - val_y2_output_root_mean_squared_error: 7.7748
# Epoch 2/500
# 614/614 [==============================] - 0s 146us/sample - loss: 30.8767 - y1_output_loss: 12.2737 - y2_output_loss: 19.1681 - y1_output_root_mean_squared_error: 3.4837 - y2_output_root_mean_squared_error: 4.3291 - val_loss: 52.5113 - val_y1_output_loss: 12.5185 - val_y2_output_loss: 40.0368 - val_y1_output_root_mean_squared_error: 3.5526 - val_y2_output_root_mean_squared_error: 6.3159
# Epoch 3/500
# 614/614 [==============================] - 0s 149us/sample - loss: 25.5711 - y1_output_loss: 9.9826 - y2_output_loss: 15.5329 - y1_output_root_mean_squared_error: 3.1646 - y2_output_root_mean_squared_error: 3.9442 - val_loss: 23.8350 - val_y1_output_loss: 8.8976 - val_y2_output_loss: 14.3574 - val_y1_output_root_mean_squared_error: 3.0097 - val_y2_output_root_mean_squared_error: 3.8441
# Epoch 4/500
# 614/614 [==============================] - 0s 142us/sample - loss: 24.6734 - y1_output_loss: 9.8743 - y2_output_loss: 14.8469 - y1_output_root_mean_squared_error: 3.1509 - y2_output_root_mean_squared_error: 3.8399 - val_loss: 42.7041 - val_y1_output_loss: 12.1836 - val_y2_output_loss: 32.5533 - val_y1_output_root_mean_squared_error: 3.4089 - val_y2_output_root_mean_squared_error: 5.5752
# Epoch 5/500
# 614/614 [==============================] - 0s 145us/sample - loss: 26.4044 - y1_output_loss: 9.9605 - y2_output_loss: 16.5541 - y1_output_root_mean_squared_error: 3.1616 - y2_output_root_mean_squared_error: 4.0508 - val_loss: 36.5658 - val_y1_output_loss: 10.4314 - val_y2_output_loss: 26.8276 - val_y1_output_root_mean_squared_error: 3.2126 - val_y2_output_root_mean_squared_error: 5.1230
# Epoch 6/500
# 614/614 [==============================] - 0s 139us/sample - loss: 22.7158 - y1_output_loss: 9.2566 - y2_output_loss: 13.3693 - y1_output_root_mean_squared_error: 3.0507 - y2_output_root_mean_squared_error: 3.6618 - val_loss: 26.6231 - val_y1_output_loss: 10.0404 - val_y2_output_loss: 17.6343 - val_y1_output_root_mean_squared_error: 3.1068 - val_y2_output_root_mean_squared_error: 4.1196
# Epoch 7/500
# 614/614 [==============================] - 0s 135us/sample - loss: 22.7067 - y1_output_loss: 8.9681 - y2_output_loss: 13.7788 - y1_output_root_mean_squared_error: 2.9974 - y2_output_root_mean_squared_error: 3.7044 - val_loss: 32.6413 - val_y1_output_loss: 10.3121 - val_y2_output_loss: 24.0622 - val_y1_output_root_mean_squared_error: 3.1223 - val_y2_output_root_mean_squared_error: 4.7846
# Epoch 8/500
# 614/614 [==============================] - 0s 132us/sample - loss: 23.5241 - y1_output_loss: 8.9589 - y2_output_loss: 15.0618 - y1_output_root_mean_squared_error: 2.9798 - y2_output_root_mean_squared_error: 3.8269 - val_loss: 35.8641 - val_y1_output_loss: 8.9061 - val_y2_output_loss: 25.8923 - val_y1_output_root_mean_squared_error: 3.0221 - val_y2_output_root_mean_squared_error: 5.1702
# Epoch 9/500
# 614/614 [==============================] - 0s 141us/sample - loss: 23.3235 - y1_output_loss: 8.8633 - y2_output_loss: 14.3325 - y1_output_root_mean_squared_error: 2.9834 - y2_output_root_mean_squared_error: 3.7978 - val_loss: 42.8538 - val_y1_output_loss: 13.1582 - val_y2_output_loss: 31.7153 - val_y1_output_root_mean_squared_error: 3.5380 - val_y2_output_root_mean_squared_error: 5.5079
# Epoch 10/500
# 614/614 [==============================] - 0s 139us/sample - loss: 20.1789 - y1_output_loss: 8.3442 - y2_output_loss: 11.7502 - y1_output_root_mean_squared_error: 2.8850 - y2_output_root_mean_squared_error: 3.4432 - val_loss: 21.5082 - val_y1_output_loss: 9.6157 - val_y2_output_loss: 12.6314 - val_y1_output_root_mean_squared_error: 3.0385 - val_y2_output_root_mean_squared_error: 3.5036
# Epoch 11/500
# 614/614 [==============================] - 0s 138us/sample - loss: 20.3295 - y1_output_loss: 8.2578 - y2_output_loss: 12.2134 - y1_output_root_mean_squared_error: 2.8735 - y2_output_root_mean_squared_error: 3.4746 - val_loss: 27.6736 - val_y1_output_loss: 8.3491 - val_y2_output_loss: 20.1813 - val_y1_output_root_mean_squared_error: 2.8493 - val_y2_output_root_mean_squared_error: 4.4221
# Epoch 12/500
# 614/614 [==============================] - 0s 137us/sample - loss: 22.5231 - y1_output_loss: 8.5272 - y2_output_loss: 13.8684 - y1_output_root_mean_squared_error: 2.9205 - y2_output_root_mean_squared_error: 3.7408 - val_loss: 18.6721 - val_y1_output_loss: 6.9453 - val_y2_output_loss: 11.3459 - val_y1_output_root_mean_squared_error: 2.6418 - val_y2_output_root_mean_squared_error: 3.4195
# Epoch 13/500
# 614/614 [==============================] - 0s 135us/sample - loss: 19.7549 - y1_output_loss: 7.8323 - y2_output_loss: 11.8743 - y1_output_root_mean_squared_error: 2.8024 - y2_output_root_mean_squared_error: 3.4499 - val_loss: 25.6773 - val_y1_output_loss: 9.3967 - val_y2_output_loss: 15.7181 - val_y1_output_root_mean_squared_error: 3.0775 - val_y2_output_root_mean_squared_error: 4.0257
# Epoch 14/500
# 614/614 [==============================] - 0s 129us/sample - loss: 19.6901 - y1_output_loss: 7.6147 - y2_output_loss: 11.9498 - y1_output_root_mean_squared_error: 2.7706 - y2_output_root_mean_squared_error: 3.4661 - val_loss: 23.6985 - val_y1_output_loss: 8.5988 - val_y2_output_loss: 14.5304 - val_y1_output_root_mean_squared_error: 2.9453 - val_y2_output_root_mean_squared_error: 3.8760
# Epoch 15/500
# 614/614 [==============================] - 0s 140us/sample - loss: 23.9466 - y1_output_loss: 8.3971 - y2_output_loss: 15.5349 - y1_output_root_mean_squared_error: 2.9053 - y2_output_root_mean_squared_error: 3.9378 - val_loss: 23.8610 - val_y1_output_loss: 8.1472 - val_y2_output_loss: 15.0280 - val_y1_output_root_mean_squared_error: 2.8809 - val_y2_output_root_mean_squared_error: 3.9448
# Epoch 16/500
# 614/614 [==============================] - 0s 139us/sample - loss: 21.1638 - y1_output_loss: 7.7486 - y2_output_loss: 13.4005 - y1_output_root_mean_squared_error: 2.7813 - y2_output_root_mean_squared_error: 3.6644 - val_loss: 17.0505 - val_y1_output_loss: 6.7167 - val_y2_output_loss: 10.1250 - val_y1_output_root_mean_squared_error: 2.5907 - val_y2_output_root_mean_squared_error: 3.2154
# Epoch 17/500
# 614/614 [==============================] - 0s 141us/sample - loss: 19.6190 - y1_output_loss: 7.4237 - y2_output_loss: 12.1817 - y1_output_root_mean_squared_error: 2.7141 - y2_output_root_mean_squared_error: 3.5004 - val_loss: 20.8207 - val_y1_output_loss: 6.6237 - val_y2_output_loss: 13.6670 - val_y1_output_root_mean_squared_error: 2.5826 - val_y2_output_root_mean_squared_error: 3.7618
# Epoch 18/500
# 614/614 [==============================] - 0s 139us/sample - loss: 20.0295 - y1_output_loss: 7.2290 - y2_output_loss: 12.7767 - y1_output_root_mean_squared_error: 2.6821 - y2_output_root_mean_squared_error: 3.5827 - val_loss: 16.2940 - val_y1_output_loss: 6.5789 - val_y2_output_loss: 9.4715 - val_y1_output_root_mean_squared_error: 2.5611 - val_y2_output_root_mean_squared_error: 3.1201
# Epoch 19/500
# 614/614 [==============================] - 0s 137us/sample - loss: 16.5978 - y1_output_loss: 6.3155 - y2_output_loss: 10.2568 - y1_output_root_mean_squared_error: 2.5208 - y2_output_root_mean_squared_error: 3.2006 - val_loss: 24.9995 - val_y1_output_loss: 7.7299 - val_y2_output_loss: 16.5482 - val_y1_output_root_mean_squared_error: 2.8055 - val_y2_output_root_mean_squared_error: 4.1387
# Epoch 20/500
# 614/614 [==============================] - 0s 136us/sample - loss: 15.9939 - y1_output_loss: 6.0905 - y2_output_loss: 9.7742 - y1_output_root_mean_squared_error: 2.4774 - y2_output_root_mean_squared_error: 3.1395 - val_loss: 15.6458 - val_y1_output_loss: 6.3841 - val_y2_output_loss: 9.0973 - val_y1_output_root_mean_squared_error: 2.5225 - val_y2_output_root_mean_squared_error: 3.0467
# Epoch 21/500
# 614/614 [==============================] - 0s 137us/sample - loss: 14.7271 - y1_output_loss: 5.8787 - y2_output_loss: 8.8429 - y1_output_root_mean_squared_error: 2.4322 - y2_output_root_mean_squared_error: 2.9684 - val_loss: 14.2299 - val_y1_output_loss: 5.3479 - val_y2_output_loss: 8.7704 - val_y1_output_root_mean_squared_error: 2.2874 - val_y2_output_root_mean_squared_error: 2.9996
# Epoch 22/500
# 614/614 [==============================] - 0s 139us/sample - loss: 16.5896 - y1_output_loss: 5.8579 - y2_output_loss: 10.6081 - y1_output_root_mean_squared_error: 2.4297 - y2_output_root_mean_squared_error: 3.2690 - val_loss: 11.3559 - val_y1_output_loss: 4.9598 - val_y2_output_loss: 6.9385 - val_y1_output_root_mean_squared_error: 2.1414 - val_y2_output_root_mean_squared_error: 2.6020
# Epoch 23/500
# 614/614 [==============================] - 0s 138us/sample - loss: 13.7653 - y1_output_loss: 5.1446 - y2_output_loss: 8.5722 - y1_output_root_mean_squared_error: 2.2740 - y2_output_root_mean_squared_error: 2.9316 - val_loss: 20.8344 - val_y1_output_loss: 6.4079 - val_y2_output_loss: 15.4684 - val_y1_output_root_mean_squared_error: 2.4523 - val_y2_output_root_mean_squared_error: 3.8498
# Epoch 24/500
# 614/614 [==============================] - 0s 140us/sample - loss: 13.2717 - y1_output_loss: 5.0614 - y2_output_loss: 8.0972 - y1_output_root_mean_squared_error: 2.2593 - y2_output_root_mean_squared_error: 2.8579 - val_loss: 14.7879 - val_y1_output_loss: 5.3940 - val_y2_output_loss: 9.9709 - val_y1_output_root_mean_squared_error: 2.2544 - val_y2_output_root_mean_squared_error: 3.1154
# Epoch 25/500
# 614/614 [==============================] - 0s 138us/sample - loss: 13.3394 - y1_output_loss: 5.2215 - y2_output_loss: 7.9987 - y1_output_root_mean_squared_error: 2.2955 - y2_output_root_mean_squared_error: 2.8408 - val_loss: 14.4356 - val_y1_output_loss: 5.4732 - val_y2_output_loss: 8.8105 - val_y1_output_root_mean_squared_error: 2.3240 - val_y2_output_root_mean_squared_error: 3.0058
# Epoch 26/500
# 614/614 [==============================] - 0s 144us/sample - loss: 13.6425 - y1_output_loss: 4.6420 - y2_output_loss: 8.9254 - y1_output_root_mean_squared_error: 2.1612 - y2_output_root_mean_squared_error: 2.9953 - val_loss: 11.1353 - val_y1_output_loss: 4.3559 - val_y2_output_loss: 6.8338 - val_y1_output_root_mean_squared_error: 2.0361 - val_y2_output_root_mean_squared_error: 2.6437
# Epoch 27/500
# 614/614 [==============================] - 0s 145us/sample - loss: 10.8486 - y1_output_loss: 4.1602 - y2_output_loss: 6.6119 - y1_output_root_mean_squared_error: 2.0474 - y2_output_root_mean_squared_error: 2.5801 - val_loss: 10.4159 - val_y1_output_loss: 4.4977 - val_y2_output_loss: 6.3852 - val_y1_output_root_mean_squared_error: 2.0456 - val_y2_output_root_mean_squared_error: 2.4963
# Epoch 28/500
# 614/614 [==============================] - 0s 131us/sample - loss: 10.4436 - y1_output_loss: 4.0727 - y2_output_loss: 6.3131 - y1_output_root_mean_squared_error: 2.0232 - y2_output_root_mean_squared_error: 2.5200 - val_loss: 9.8784 - val_y1_output_loss: 4.0178 - val_y2_output_loss: 5.8493 - val_y1_output_root_mean_squared_error: 1.9738 - val_y2_output_root_mean_squared_error: 2.4459
# Epoch 29/500
# 614/614 [==============================] - 0s 140us/sample - loss: 14.3252 - y1_output_loss: 4.8076 - y2_output_loss: 9.5441 - y1_output_root_mean_squared_error: 2.1802 - y2_output_root_mean_squared_error: 3.0938 - val_loss: 13.2209 - val_y1_output_loss: 4.4685 - val_y2_output_loss: 8.4999 - val_y1_output_root_mean_squared_error: 2.1095 - val_y2_output_root_mean_squared_error: 2.9616
# Epoch 30/500
# 614/614 [==============================] - 0s 138us/sample - loss: 12.5342 - y1_output_loss: 4.3665 - y2_output_loss: 8.0747 - y1_output_root_mean_squared_error: 2.0978 - y2_output_root_mean_squared_error: 2.8519 - val_loss: 16.3352 - val_y1_output_loss: 6.2617 - val_y2_output_loss: 10.3044 - val_y1_output_root_mean_squared_error: 2.4602 - val_y2_output_root_mean_squared_error: 3.2067
# Epoch 31/500
# 614/614 [==============================] - 0s 147us/sample - loss: 10.0949 - y1_output_loss: 4.0707 - y2_output_loss: 6.1095 - y1_output_root_mean_squared_error: 1.9871 - y2_output_root_mean_squared_error: 2.4791 - val_loss: 21.0922 - val_y1_output_loss: 8.0357 - val_y2_output_loss: 12.6007 - val_y1_output_root_mean_squared_error: 2.8519 - val_y2_output_root_mean_squared_error: 3.5998
# Epoch 32/500
# 614/614 [==============================] - 0s 135us/sample - loss: 11.5798 - y1_output_loss: 3.8575 - y2_output_loss: 7.7160 - y1_output_root_mean_squared_error: 1.9621 - y2_output_root_mean_squared_error: 2.7803 - val_loss: 8.1274 - val_y1_output_loss: 3.3605 - val_y2_output_loss: 4.7304 - val_y1_output_root_mean_squared_error: 1.8150 - val_y2_output_root_mean_squared_error: 2.1985
# Epoch 33/500
# 614/614 [==============================] - 0s 138us/sample - loss: 11.5960 - y1_output_loss: 4.0294 - y2_output_loss: 7.5414 - y1_output_root_mean_squared_error: 2.0091 - y2_output_root_mean_squared_error: 2.7495 - val_loss: 12.7460 - val_y1_output_loss: 3.5713 - val_y2_output_loss: 8.9951 - val_y1_output_root_mean_squared_error: 1.8714 - val_y2_output_root_mean_squared_error: 3.0404
# Epoch 34/500
# 614/614 [==============================] - 0s 145us/sample - loss: 11.8676 - y1_output_loss: 3.9062 - y2_output_loss: 7.8586 - y1_output_root_mean_squared_error: 1.9845 - y2_output_root_mean_squared_error: 2.8159 - val_loss: 9.0052 - val_y1_output_loss: 3.8008 - val_y2_output_loss: 5.4256 - val_y1_output_root_mean_squared_error: 1.8993 - val_y2_output_root_mean_squared_error: 2.3233
# Epoch 35/500
# 614/614 [==============================] - 0s 132us/sample - loss: 9.9452 - y1_output_loss: 3.5910 - y2_output_loss: 6.3309 - y1_output_root_mean_squared_error: 1.8938 - y2_output_root_mean_squared_error: 2.5217 - val_loss: 11.0951 - val_y1_output_loss: 2.8858 - val_y2_output_loss: 8.0480 - val_y1_output_root_mean_squared_error: 1.6811 - val_y2_output_root_mean_squared_error: 2.8756
# Epoch 36/500
# 614/614 [==============================] - 0s 139us/sample - loss: 10.8771 - y1_output_loss: 3.8194 - y2_output_loss: 6.9740 - y1_output_root_mean_squared_error: 1.9615 - y2_output_root_mean_squared_error: 2.6513 - val_loss: 10.5454 - val_y1_output_loss: 3.8095 - val_y2_output_loss: 7.0490 - val_y1_output_root_mean_squared_error: 1.8996 - val_y2_output_root_mean_squared_error: 2.6338
# Epoch 37/500
# 614/614 [==============================] - 0s 139us/sample - loss: 9.2619 - y1_output_loss: 3.0822 - y2_output_loss: 6.1457 - y1_output_root_mean_squared_error: 1.7611 - y2_output_root_mean_squared_error: 2.4820 - val_loss: 7.5993 - val_y1_output_loss: 3.0774 - val_y2_output_loss: 4.4102 - val_y1_output_root_mean_squared_error: 1.7430 - val_y2_output_root_mean_squared_error: 2.1357
# Epoch 38/500
# 614/614 [==============================] - 0s 138us/sample - loss: 10.0404 - y1_output_loss: 3.2199 - y2_output_loss: 6.7777 - y1_output_root_mean_squared_error: 1.8004 - y2_output_root_mean_squared_error: 2.6075 - val_loss: 10.5555 - val_y1_output_loss: 3.1629 - val_y2_output_loss: 7.5877 - val_y1_output_root_mean_squared_error: 1.7407 - val_y2_output_root_mean_squared_error: 2.7433
# Epoch 39/500
# 614/614 [==============================] - 0s 145us/sample - loss: 10.1090 - y1_output_loss: 3.3012 - y2_output_loss: 6.8716 - y1_output_root_mean_squared_error: 1.8101 - y2_output_root_mean_squared_error: 2.6139 - val_loss: 10.6409 - val_y1_output_loss: 3.5246 - val_y2_output_loss: 6.9251 - val_y1_output_root_mean_squared_error: 1.8730 - val_y2_output_root_mean_squared_error: 2.6707
# Epoch 40/500
# 614/614 [==============================] - 0s 138us/sample - loss: 8.5521 - y1_output_loss: 2.8995 - y2_output_loss: 5.6461 - y1_output_root_mean_squared_error: 1.6991 - y2_output_root_mean_squared_error: 2.3802 - val_loss: 20.5577 - val_y1_output_loss: 7.0593 - val_y2_output_loss: 12.9069 - val_y1_output_root_mean_squared_error: 2.6857 - val_y2_output_root_mean_squared_error: 3.6530
# Epoch 41/500
# 614/614 [==============================] - 0s 147us/sample - loss: 7.8393 - y1_output_loss: 2.7028 - y2_output_loss: 5.0920 - y1_output_root_mean_squared_error: 1.6498 - y2_output_root_mean_squared_error: 2.2622 - val_loss: 7.5361 - val_y1_output_loss: 2.6827 - val_y2_output_loss: 4.8784 - val_y1_output_root_mean_squared_error: 1.6087 - val_y2_output_root_mean_squared_error: 2.2244
# Epoch 42/500
# 614/614 [==============================] - 0s 138us/sample - loss: 7.5657 - y1_output_loss: 2.5284 - y2_output_loss: 5.0119 - y1_output_root_mean_squared_error: 1.5891 - y2_output_root_mean_squared_error: 2.2451 - val_loss: 7.1787 - val_y1_output_loss: 2.8741 - val_y2_output_loss: 4.2636 - val_y1_output_root_mean_squared_error: 1.6743 - val_y2_output_root_mean_squared_error: 2.0918
# Epoch 43/500
# 614/614 [==============================] - 0s 137us/sample - loss: 8.9128 - y1_output_loss: 2.8958 - y2_output_loss: 5.9885 - y1_output_root_mean_squared_error: 1.7062 - y2_output_root_mean_squared_error: 2.4499 - val_loss: 7.1740 - val_y1_output_loss: 2.2094 - val_y2_output_loss: 5.0048 - val_y1_output_root_mean_squared_error: 1.4651 - val_y2_output_root_mean_squared_error: 2.2422
# Epoch 44/500
# 614/614 [==============================] - 0s 142us/sample - loss: 7.8472 - y1_output_loss: 2.7327 - y2_output_loss: 5.1478 - y1_output_root_mean_squared_error: 1.6424 - y2_output_root_mean_squared_error: 2.2693 - val_loss: 10.8428 - val_y1_output_loss: 2.5137 - val_y2_output_loss: 8.0565 - val_y1_output_root_mean_squared_error: 1.5833 - val_y2_output_root_mean_squared_error: 2.8872
# Epoch 45/500
# 614/614 [==============================] - 0s 146us/sample - loss: 7.9462 - y1_output_loss: 2.6419 - y2_output_loss: 5.3576 - y1_output_root_mean_squared_error: 1.6044 - y2_output_root_mean_squared_error: 2.3178 - val_loss: 6.3817 - val_y1_output_loss: 2.3040 - val_y2_output_loss: 4.1992 - val_y1_output_root_mean_squared_error: 1.4794 - val_y2_output_root_mean_squared_error: 2.0477
# Epoch 46/500
# 614/614 [==============================] - 0s 143us/sample - loss: 7.0115 - y1_output_loss: 2.3363 - y2_output_loss: 4.6760 - y1_output_root_mean_squared_error: 1.5192 - y2_output_root_mean_squared_error: 2.1687 - val_loss: 12.7830 - val_y1_output_loss: 4.1043 - val_y2_output_loss: 8.4644 - val_y1_output_root_mean_squared_error: 2.0286 - val_y2_output_root_mean_squared_error: 2.9441
# Epoch 47/500
# 614/614 [==============================] - 0s 139us/sample - loss: 8.1492 - y1_output_loss: 2.5316 - y2_output_loss: 5.6121 - y1_output_root_mean_squared_error: 1.5850 - y2_output_root_mean_squared_error: 2.3742 - val_loss: 13.5377 - val_y1_output_loss: 4.4177 - val_y2_output_loss: 8.7470 - val_y1_output_root_mean_squared_error: 2.1244 - val_y2_output_root_mean_squared_error: 3.0041
# Epoch 48/500
# 614/614 [==============================] - 0s 142us/sample - loss: 8.0733 - y1_output_loss: 2.7994 - y2_output_loss: 5.3116 - y1_output_root_mean_squared_error: 1.6573 - y2_output_root_mean_squared_error: 2.3079 - val_loss: 10.2793 - val_y1_output_loss: 4.8189 - val_y2_output_loss: 5.5393 - val_y1_output_root_mean_squared_error: 2.1689 - val_y2_output_root_mean_squared_error: 2.3612
# Epoch 49/500
# 614/614 [==============================] - 0s 135us/sample - loss: 7.4833 - y1_output_loss: 2.2494 - y2_output_loss: 5.2593 - y1_output_root_mean_squared_error: 1.4957 - y2_output_root_mean_squared_error: 2.2905 - val_loss: 10.9360 - val_y1_output_loss: 2.8372 - val_y2_output_loss: 8.3218 - val_y1_output_root_mean_squared_error: 1.6416 - val_y2_output_root_mean_squared_error: 2.8707
# Epoch 50/500
# 614/614 [==============================] - 0s 128us/sample - loss: 6.5998 - y1_output_loss: 2.1173 - y2_output_loss: 4.4686 - y1_output_root_mean_squared_error: 1.4589 - y2_output_root_mean_squared_error: 2.1146 - val_loss: 19.2766 - val_y1_output_loss: 5.2751 - val_y2_output_loss: 14.1239 - val_y1_output_root_mean_squared_error: 2.2797 - val_y2_output_root_mean_squared_error: 3.7523
# Epoch 51/500
# 614/614 [==============================] - 0s 138us/sample - loss: 7.4552 - y1_output_loss: 2.2112 - y2_output_loss: 5.2436 - y1_output_root_mean_squared_error: 1.4921 - y2_output_root_mean_squared_error: 2.2866 - val_loss: 14.6833 - val_y1_output_loss: 2.5552 - val_y2_output_loss: 12.1905 - val_y1_output_root_mean_squared_error: 1.5807 - val_y2_output_root_mean_squared_error: 3.4907
# Epoch 52/500
# 614/614 [==============================] - 0s 147us/sample - loss: 7.8375 - y1_output_loss: 2.6206 - y2_output_loss: 5.1919 - y1_output_root_mean_squared_error: 1.6243 - y2_output_root_mean_squared_error: 2.2802 - val_loss: 5.6741 - val_y1_output_loss: 1.9077 - val_y2_output_loss: 3.6383 - val_y1_output_root_mean_squared_error: 1.3807 - val_y2_output_root_mean_squared_error: 1.9411
# Epoch 53/500
# 614/614 [==============================] - 0s 141us/sample - loss: 6.7138 - y1_output_loss: 2.0262 - y2_output_loss: 4.6589 - y1_output_root_mean_squared_error: 1.4238 - y2_output_root_mean_squared_error: 2.1648 - val_loss: 6.0632 - val_y1_output_loss: 2.4727 - val_y2_output_loss: 3.6087 - val_y1_output_root_mean_squared_error: 1.5377 - val_y2_output_root_mean_squared_error: 1.9232
# Epoch 54/500
# 614/614 [==============================] - 0s 139us/sample - loss: 6.6880 - y1_output_loss: 2.0494 - y2_output_loss: 4.5804 - y1_output_root_mean_squared_error: 1.4382 - y2_output_root_mean_squared_error: 2.1493 - val_loss: 5.3359 - val_y1_output_loss: 1.6362 - val_y2_output_loss: 3.5871 - val_y1_output_root_mean_squared_error: 1.2719 - val_y2_output_root_mean_squared_error: 1.9283
# Epoch 55/500
# 614/614 [==============================] - 0s 137us/sample - loss: 6.5766 - y1_output_loss: 1.9397 - y2_output_loss: 4.5836 - y1_output_root_mean_squared_error: 1.3974 - y2_output_root_mean_squared_error: 2.1503 - val_loss: 5.7822 - val_y1_output_loss: 2.0410 - val_y2_output_loss: 3.7207 - val_y1_output_root_mean_squared_error: 1.4116 - val_y2_output_root_mean_squared_error: 1.9467
# Epoch 56/500
# 614/614 [==============================] - 0s 146us/sample - loss: 6.3458 - y1_output_loss: 1.9131 - y2_output_loss: 4.4075 - y1_output_root_mean_squared_error: 1.3817 - y2_output_root_mean_squared_error: 2.1064 - val_loss: 5.7960 - val_y1_output_loss: 1.6996 - val_y2_output_loss: 3.9667 - val_y1_output_root_mean_squared_error: 1.3064 - val_y2_output_root_mean_squared_error: 2.0222
# Epoch 57/500
# 614/614 [==============================] - 0s 141us/sample - loss: 5.0196 - y1_output_loss: 1.5754 - y2_output_loss: 3.4730 - y1_output_root_mean_squared_error: 1.2533 - y2_output_root_mean_squared_error: 1.8571 - val_loss: 6.4960 - val_y1_output_loss: 1.9946 - val_y2_output_loss: 4.3243 - val_y1_output_root_mean_squared_error: 1.4177 - val_y2_output_root_mean_squared_error: 2.1181
# Epoch 58/500
# 614/614 [==============================] - 0s 139us/sample - loss: 5.5143 - y1_output_loss: 1.6445 - y2_output_loss: 3.9507 - y1_output_root_mean_squared_error: 1.2834 - y2_output_root_mean_squared_error: 1.9665 - val_loss: 5.7646 - val_y1_output_loss: 1.6690 - val_y2_output_loss: 3.9398 - val_y1_output_root_mean_squared_error: 1.2952 - val_y2_output_root_mean_squared_error: 2.0216
# Epoch 59/500
# 614/614 [==============================] - 0s 142us/sample - loss: 5.5589 - y1_output_loss: 1.6435 - y2_output_loss: 3.8700 - y1_output_root_mean_squared_error: 1.2862 - y2_output_root_mean_squared_error: 1.9760 - val_loss: 5.8240 - val_y1_output_loss: 1.5155 - val_y2_output_loss: 4.1291 - val_y1_output_root_mean_squared_error: 1.2397 - val_y2_output_root_mean_squared_error: 2.0706
# Epoch 60/500
# 614/614 [==============================] - 0s 141us/sample - loss: 5.9706 - y1_output_loss: 1.6789 - y2_output_loss: 4.2703 - y1_output_root_mean_squared_error: 1.2981 - y2_output_root_mean_squared_error: 2.0701 - val_loss: 7.8313 - val_y1_output_loss: 2.6940 - val_y2_output_loss: 5.1070 - val_y1_output_root_mean_squared_error: 1.6240 - val_y2_output_root_mean_squared_error: 2.2790
# Epoch 61/500
# 614/614 [==============================] - 0s 138us/sample - loss: 5.0784 - y1_output_loss: 1.5981 - y2_output_loss: 3.5720 - y1_output_root_mean_squared_error: 1.2529 - y2_output_root_mean_squared_error: 1.8732 - val_loss: 17.7715 - val_y1_output_loss: 7.2058 - val_y2_output_loss: 10.0259 - val_y1_output_root_mean_squared_error: 2.7203 - val_y2_output_root_mean_squared_error: 3.2205
# Epoch 62/500
# 614/614 [==============================] - 0s 141us/sample - loss: 6.0596 - y1_output_loss: 1.9564 - y2_output_loss: 4.1274 - y1_output_root_mean_squared_error: 1.3881 - y2_output_root_mean_squared_error: 2.0329 - val_loss: 11.8696 - val_y1_output_loss: 3.5261 - val_y2_output_loss: 8.0497 - val_y1_output_root_mean_squared_error: 1.9000 - val_y2_output_root_mean_squared_error: 2.8739
# Epoch 63/500
# 614/614 [==============================] - 0s 140us/sample - loss: 6.7603 - y1_output_loss: 2.0344 - y2_output_loss: 4.7556 - y1_output_root_mean_squared_error: 1.4305 - y2_output_root_mean_squared_error: 2.1712 - val_loss: 14.6961 - val_y1_output_loss: 4.2042 - val_y2_output_loss: 10.0110 - val_y1_output_root_mean_squared_error: 2.0816 - val_y2_output_root_mean_squared_error: 3.2192
# Epoch 64/500
# 614/614 [==============================] - 0s 145us/sample - loss: 6.9507 - y1_output_loss: 1.9549 - y2_output_loss: 4.9693 - y1_output_root_mean_squared_error: 1.4037 - y2_output_root_mean_squared_error: 2.2317 - val_loss: 5.2248 - val_y1_output_loss: 1.5827 - val_y2_output_loss: 3.5246 - val_y1_output_root_mean_squared_error: 1.2532 - val_y2_output_root_mean_squared_error: 1.9116
# Epoch 65/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.7745 - y1_output_loss: 1.3317 - y2_output_loss: 3.4282 - y1_output_root_mean_squared_error: 1.1574 - y2_output_root_mean_squared_error: 1.8533 - val_loss: 5.7128 - val_y1_output_loss: 1.1285 - val_y2_output_loss: 4.4483 - val_y1_output_root_mean_squared_error: 1.0601 - val_y2_output_root_mean_squared_error: 2.1422
# Epoch 66/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.6290 - y1_output_loss: 1.3023 - y2_output_loss: 3.3971 - y1_output_root_mean_squared_error: 1.1369 - y2_output_root_mean_squared_error: 1.8266 - val_loss: 21.9262 - val_y1_output_loss: 6.2441 - val_y2_output_loss: 15.0830 - val_y1_output_root_mean_squared_error: 2.5283 - val_y2_output_root_mean_squared_error: 3.9413
# Epoch 67/500
# 614/614 [==============================] - 0s 146us/sample - loss: 7.6150 - y1_output_loss: 1.9004 - y2_output_loss: 5.6568 - y1_output_root_mean_squared_error: 1.3820 - y2_output_root_mean_squared_error: 2.3885 - val_loss: 9.1794 - val_y1_output_loss: 3.2007 - val_y2_output_loss: 5.9708 - val_y1_output_root_mean_squared_error: 1.7775 - val_y2_output_root_mean_squared_error: 2.4535
# Epoch 68/500
# 614/614 [==============================] - 0s 137us/sample - loss: 4.9552 - y1_output_loss: 1.4228 - y2_output_loss: 3.5029 - y1_output_root_mean_squared_error: 1.1955 - y2_output_root_mean_squared_error: 1.8778 - val_loss: 5.0320 - val_y1_output_loss: 1.2009 - val_y2_output_loss: 3.6872 - val_y1_output_root_mean_squared_error: 1.0994 - val_y2_output_root_mean_squared_error: 1.9553
# Epoch 69/500
# 614/614 [==============================] - 0s 138us/sample - loss: 6.9530 - y1_output_loss: 1.9872 - y2_output_loss: 4.9260 - y1_output_root_mean_squared_error: 1.4092 - y2_output_root_mean_squared_error: 2.2287 - val_loss: 7.3058 - val_y1_output_loss: 1.9741 - val_y2_output_loss: 5.2640 - val_y1_output_root_mean_squared_error: 1.4072 - val_y2_output_root_mean_squared_error: 2.3077
# Epoch 70/500
# 614/614 [==============================] - 0s 143us/sample - loss: 4.7359 - y1_output_loss: 1.2210 - y2_output_loss: 3.7834 - y1_output_root_mean_squared_error: 1.0866 - y2_output_root_mean_squared_error: 1.8855 - val_loss: 41.9407 - val_y1_output_loss: 7.8067 - val_y2_output_loss: 33.3438 - val_y1_output_root_mean_squared_error: 2.8296 - val_y2_output_root_mean_squared_error: 5.8253
# Epoch 71/500
# 614/614 [==============================] - 0s 141us/sample - loss: 6.6021 - y1_output_loss: 1.8451 - y2_output_loss: 4.7514 - y1_output_root_mean_squared_error: 1.3510 - y2_output_root_mean_squared_error: 2.1856 - val_loss: 5.1635 - val_y1_output_loss: 1.3636 - val_y2_output_loss: 3.8197 - val_y1_output_root_mean_squared_error: 1.1557 - val_y2_output_root_mean_squared_error: 1.9565
# Epoch 72/500
# 614/614 [==============================] - 0s 136us/sample - loss: 4.3166 - y1_output_loss: 1.1344 - y2_output_loss: 3.2298 - y1_output_root_mean_squared_error: 1.0640 - y2_output_root_mean_squared_error: 1.7845 - val_loss: 8.5463 - val_y1_output_loss: 1.2186 - val_y2_output_loss: 7.0835 - val_y1_output_root_mean_squared_error: 1.1110 - val_y2_output_root_mean_squared_error: 2.7041
# Epoch 73/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.1633 - y1_output_loss: 1.1078 - y2_output_loss: 3.0222 - y1_output_root_mean_squared_error: 1.0559 - y2_output_root_mean_squared_error: 1.7459 - val_loss: 3.2487 - val_y1_output_loss: 0.7856 - val_y2_output_loss: 2.3712 - val_y1_output_root_mean_squared_error: 0.8921 - val_y2_output_root_mean_squared_error: 1.5662
# Epoch 74/500
# 614/614 [==============================] - 0s 141us/sample - loss: 4.0678 - y1_output_loss: 0.9642 - y2_output_loss: 3.1292 - y1_output_root_mean_squared_error: 0.9739 - y2_output_root_mean_squared_error: 1.7662 - val_loss: 14.7222 - val_y1_output_loss: 4.0108 - val_y2_output_loss: 10.2689 - val_y1_output_root_mean_squared_error: 2.0321 - val_y2_output_root_mean_squared_error: 3.2546
# Epoch 75/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.8396 - y1_output_loss: 0.9194 - y2_output_loss: 2.9065 - y1_output_root_mean_squared_error: 0.9569 - y2_output_root_mean_squared_error: 1.7099 - val_loss: 7.1115 - val_y1_output_loss: 1.8788 - val_y2_output_loss: 5.0192 - val_y1_output_root_mean_squared_error: 1.3869 - val_y2_output_root_mean_squared_error: 2.2777
# Epoch 76/500
# 614/614 [==============================] - 0s 138us/sample - loss: 5.8680 - y1_output_loss: 1.7802 - y2_output_loss: 4.1277 - y1_output_root_mean_squared_error: 1.3397 - y2_output_root_mean_squared_error: 2.0182 - val_loss: 8.5676 - val_y1_output_loss: 2.2621 - val_y2_output_loss: 6.5495 - val_y1_output_root_mean_squared_error: 1.4745 - val_y2_output_root_mean_squared_error: 2.5285
# Epoch 77/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.6266 - y1_output_loss: 0.8858 - y2_output_loss: 2.7643 - y1_output_root_mean_squared_error: 0.9434 - y2_output_root_mean_squared_error: 1.6543 - val_loss: 3.9150 - val_y1_output_loss: 0.6707 - val_y2_output_loss: 3.1332 - val_y1_output_root_mean_squared_error: 0.8224 - val_y2_output_root_mean_squared_error: 1.7996
# Epoch 78/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.4186 - y1_output_loss: 0.8432 - y2_output_loss: 2.6284 - y1_output_root_mean_squared_error: 0.9184 - y2_output_root_mean_squared_error: 1.6047 - val_loss: 3.7091 - val_y1_output_loss: 0.7180 - val_y2_output_loss: 3.0114 - val_y1_output_root_mean_squared_error: 0.8423 - val_y2_output_root_mean_squared_error: 1.7319
# Epoch 79/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.5927 - y1_output_loss: 1.1264 - y2_output_loss: 3.4513 - y1_output_root_mean_squared_error: 1.0642 - y2_output_root_mean_squared_error: 1.8602 - val_loss: 4.6194 - val_y1_output_loss: 0.8535 - val_y2_output_loss: 3.8463 - val_y1_output_root_mean_squared_error: 0.9091 - val_y2_output_root_mean_squared_error: 1.9475
# Epoch 80/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.6229 - y1_output_loss: 0.8908 - y2_output_loss: 2.7178 - y1_output_root_mean_squared_error: 0.9435 - y2_output_root_mean_squared_error: 1.6531 - val_loss: 6.0675 - val_y1_output_loss: 1.7345 - val_y2_output_loss: 4.1381 - val_y1_output_root_mean_squared_error: 1.3349 - val_y2_output_root_mean_squared_error: 2.0702
# Epoch 81/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.4891 - y1_output_loss: 0.8699 - y2_output_loss: 2.6749 - y1_output_root_mean_squared_error: 0.9351 - y2_output_root_mean_squared_error: 1.6170 - val_loss: 11.1626 - val_y1_output_loss: 1.2365 - val_y2_output_loss: 10.1655 - val_y1_output_root_mean_squared_error: 1.0914 - val_y2_output_root_mean_squared_error: 3.1577
# Epoch 82/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.6369 - y1_output_loss: 0.8830 - y2_output_loss: 2.7399 - y1_output_root_mean_squared_error: 0.9389 - y2_output_root_mean_squared_error: 1.6599 - val_loss: 3.0793 - val_y1_output_loss: 0.6267 - val_y2_output_loss: 2.4062 - val_y1_output_root_mean_squared_error: 0.7976 - val_y2_output_root_mean_squared_error: 1.5631
# Epoch 83/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.3735 - y1_output_loss: 0.7455 - y2_output_loss: 2.6243 - y1_output_root_mean_squared_error: 0.8632 - y2_output_root_mean_squared_error: 1.6213 - val_loss: 2.9892 - val_y1_output_loss: 0.6711 - val_y2_output_loss: 2.2316 - val_y1_output_root_mean_squared_error: 0.8258 - val_y2_output_root_mean_squared_error: 1.5190
# Epoch 84/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.7973 - y1_output_loss: 1.0896 - y2_output_loss: 2.7293 - y1_output_root_mean_squared_error: 1.0258 - y2_output_root_mean_squared_error: 1.6568 - val_loss: 22.4873 - val_y1_output_loss: 7.0404 - val_y2_output_loss: 15.0669 - val_y1_output_root_mean_squared_error: 2.6847 - val_y2_output_root_mean_squared_error: 3.9090
# Epoch 85/500
# 614/614 [==============================] - 0s 138us/sample - loss: 14.9836 - y1_output_loss: 3.8860 - y2_output_loss: 11.0299 - y1_output_root_mean_squared_error: 1.9806 - y2_output_root_mean_squared_error: 3.3258 - val_loss: 6.8864 - val_y1_output_loss: 1.1345 - val_y2_output_loss: 5.7506 - val_y1_output_root_mean_squared_error: 1.0604 - val_y2_output_root_mean_squared_error: 2.4004
# Epoch 86/500
# 614/614 [==============================] - 0s 138us/sample - loss: 5.9100 - y1_output_loss: 1.6057 - y2_output_loss: 4.2549 - y1_output_root_mean_squared_error: 1.2717 - y2_output_root_mean_squared_error: 2.0719 - val_loss: 5.0098 - val_y1_output_loss: 0.7885 - val_y2_output_loss: 4.0637 - val_y1_output_root_mean_squared_error: 0.8943 - val_y2_output_root_mean_squared_error: 2.0518
# Epoch 87/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.2130 - y1_output_loss: 1.1432 - y2_output_loss: 3.0589 - y1_output_root_mean_squared_error: 1.0725 - y2_output_root_mean_squared_error: 1.7501 - val_loss: 5.8467 - val_y1_output_loss: 1.0620 - val_y2_output_loss: 4.6356 - val_y1_output_root_mean_squared_error: 1.0465 - val_y2_output_root_mean_squared_error: 2.1798
# Epoch 88/500
# 614/614 [==============================] - 0s 140us/sample - loss: 6.9288 - y1_output_loss: 2.0438 - y2_output_loss: 4.8688 - y1_output_root_mean_squared_error: 1.4361 - y2_output_root_mean_squared_error: 2.2060 - val_loss: 4.2176 - val_y1_output_loss: 0.7545 - val_y2_output_loss: 3.4228 - val_y1_output_root_mean_squared_error: 0.8756 - val_y2_output_root_mean_squared_error: 1.8576
# Epoch 89/500
# 614/614 [==============================] - 0s 139us/sample - loss: 4.7865 - y1_output_loss: 1.1301 - y2_output_loss: 3.6826 - y1_output_root_mean_squared_error: 1.0585 - y2_output_root_mean_squared_error: 1.9147 - val_loss: 5.1416 - val_y1_output_loss: 1.1588 - val_y2_output_loss: 4.0403 - val_y1_output_root_mean_squared_error: 1.0635 - val_y2_output_root_mean_squared_error: 2.0026
# Epoch 90/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.4272 - y1_output_loss: 0.8475 - y2_output_loss: 2.5686 - y1_output_root_mean_squared_error: 0.9242 - y2_output_root_mean_squared_error: 1.6041 - val_loss: 2.5476 - val_y1_output_loss: 0.5287 - val_y2_output_loss: 1.9566 - val_y1_output_root_mean_squared_error: 0.7278 - val_y2_output_root_mean_squared_error: 1.4205
# Epoch 91/500
# 614/614 [==============================] - 0s 136us/sample - loss: 4.2891 - y1_output_loss: 1.1482 - y2_output_loss: 3.1365 - y1_output_root_mean_squared_error: 1.0653 - y2_output_root_mean_squared_error: 1.7760 - val_loss: 6.4801 - val_y1_output_loss: 1.7725 - val_y2_output_loss: 4.7548 - val_y1_output_root_mean_squared_error: 1.3265 - val_y2_output_root_mean_squared_error: 2.1726
# Epoch 92/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.1918 - y1_output_loss: 0.8003 - y2_output_loss: 2.3686 - y1_output_root_mean_squared_error: 0.8959 - y2_output_root_mean_squared_error: 1.5457 - val_loss: 3.5546 - val_y1_output_loss: 1.0875 - val_y2_output_loss: 2.3922 - val_y1_output_root_mean_squared_error: 1.0592 - val_y2_output_root_mean_squared_error: 1.5597
# Epoch 93/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.6673 - y1_output_loss: 0.6047 - y2_output_loss: 2.0536 - y1_output_root_mean_squared_error: 0.7803 - y2_output_root_mean_squared_error: 1.4347 - val_loss: 4.2395 - val_y1_output_loss: 0.7252 - val_y2_output_loss: 3.3912 - val_y1_output_root_mean_squared_error: 0.8592 - val_y2_output_root_mean_squared_error: 1.8712
# Epoch 94/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.7658 - y1_output_loss: 0.8212 - y2_output_loss: 2.9241 - y1_output_root_mean_squared_error: 0.9102 - y2_output_root_mean_squared_error: 1.7138 - val_loss: 10.4969 - val_y1_output_loss: 2.2955 - val_y2_output_loss: 7.9217 - val_y1_output_root_mean_squared_error: 1.5325 - val_y2_output_root_mean_squared_error: 2.8546
# Epoch 95/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.4078 - y1_output_loss: 0.7843 - y2_output_loss: 2.6050 - y1_output_root_mean_squared_error: 0.8883 - y2_output_root_mean_squared_error: 1.6182 - val_loss: 3.4418 - val_y1_output_loss: 0.8755 - val_y2_output_loss: 2.5865 - val_y1_output_root_mean_squared_error: 0.9244 - val_y2_output_root_mean_squared_error: 1.6085
# Epoch 96/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.1839 - y1_output_loss: 0.6808 - y2_output_loss: 2.5093 - y1_output_root_mean_squared_error: 0.8250 - y2_output_root_mean_squared_error: 1.5822 - val_loss: 5.6710 - val_y1_output_loss: 0.6963 - val_y2_output_loss: 5.0658 - val_y1_output_root_mean_squared_error: 0.8326 - val_y2_output_root_mean_squared_error: 2.2311
# Epoch 97/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.9954 - y1_output_loss: 0.7334 - y2_output_loss: 2.2713 - y1_output_root_mean_squared_error: 0.8590 - y2_output_root_mean_squared_error: 1.5025 - val_loss: 2.5854 - val_y1_output_loss: 0.5660 - val_y2_output_loss: 1.9465 - val_y1_output_root_mean_squared_error: 0.7560 - val_y2_output_root_mean_squared_error: 1.4191
# Epoch 98/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.4921 - y1_output_loss: 0.8689 - y2_output_loss: 2.6310 - y1_output_root_mean_squared_error: 0.9277 - y2_output_root_mean_squared_error: 1.6222 - val_loss: 11.7059 - val_y1_output_loss: 3.9233 - val_y2_output_loss: 7.4726 - val_y1_output_root_mean_squared_error: 2.0098 - val_y2_output_root_mean_squared_error: 2.7688
# Epoch 99/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.9181 - y1_output_loss: 0.9762 - y2_output_loss: 2.9278 - y1_output_root_mean_squared_error: 0.9866 - y2_output_root_mean_squared_error: 1.7160 - val_loss: 3.2071 - val_y1_output_loss: 0.7798 - val_y2_output_loss: 2.3337 - val_y1_output_root_mean_squared_error: 0.8972 - val_y2_output_root_mean_squared_error: 1.5499
# Epoch 100/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.1961 - y1_output_loss: 0.7244 - y2_output_loss: 2.4521 - y1_output_root_mean_squared_error: 0.8520 - y2_output_root_mean_squared_error: 1.5717 - val_loss: 3.8568 - val_y1_output_loss: 1.3402 - val_y2_output_loss: 2.4548 - val_y1_output_root_mean_squared_error: 1.1648 - val_y2_output_root_mean_squared_error: 1.5811
# Epoch 101/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.5461 - y1_output_loss: 0.5594 - y2_output_loss: 1.9714 - y1_output_root_mean_squared_error: 0.7487 - y2_output_root_mean_squared_error: 1.4091 - val_loss: 2.4025 - val_y1_output_loss: 0.4218 - val_y2_output_loss: 1.9823 - val_y1_output_root_mean_squared_error: 0.6506 - val_y2_output_root_mean_squared_error: 1.4068
# Epoch 102/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.7514 - y1_output_loss: 1.0436 - y2_output_loss: 2.8455 - y1_output_root_mean_squared_error: 0.9887 - y2_output_root_mean_squared_error: 1.6655 - val_loss: 36.8198 - val_y1_output_loss: 11.7660 - val_y2_output_loss: 25.1268 - val_y1_output_root_mean_squared_error: 3.4341 - val_y2_output_root_mean_squared_error: 5.0027
# Epoch 103/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.4679 - y1_output_loss: 0.8286 - y2_output_loss: 2.6134 - y1_output_root_mean_squared_error: 0.9124 - y2_output_root_mean_squared_error: 1.6234 - val_loss: 2.7781 - val_y1_output_loss: 0.6583 - val_y2_output_loss: 2.0570 - val_y1_output_root_mean_squared_error: 0.8204 - val_y2_output_root_mean_squared_error: 1.4509
# Epoch 104/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.1582 - y1_output_loss: 0.4834 - y2_output_loss: 1.6833 - y1_output_root_mean_squared_error: 0.6921 - y2_output_root_mean_squared_error: 1.2958 - val_loss: 2.4424 - val_y1_output_loss: 0.5351 - val_y2_output_loss: 1.8664 - val_y1_output_root_mean_squared_error: 0.7403 - val_y2_output_root_mean_squared_error: 1.3764
# Epoch 105/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.6721 - y1_output_loss: 0.5677 - y2_output_loss: 2.0918 - y1_output_root_mean_squared_error: 0.7557 - y2_output_root_mean_squared_error: 1.4495 - val_loss: 2.5541 - val_y1_output_loss: 0.5381 - val_y2_output_loss: 1.9708 - val_y1_output_root_mean_squared_error: 0.7326 - val_y2_output_root_mean_squared_error: 1.4203
# Epoch 106/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.3364 - y1_output_loss: 0.5230 - y2_output_loss: 1.8277 - y1_output_root_mean_squared_error: 0.7231 - y2_output_root_mean_squared_error: 1.3467 - val_loss: 9.7861 - val_y1_output_loss: 1.1896 - val_y2_output_loss: 8.5842 - val_y1_output_root_mean_squared_error: 1.0966 - val_y2_output_root_mean_squared_error: 2.9298
# Epoch 107/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.7825 - y1_output_loss: 0.8037 - y2_output_loss: 2.9858 - y1_output_root_mean_squared_error: 0.8976 - y2_output_root_mean_squared_error: 1.7253 - val_loss: 5.1393 - val_y1_output_loss: 0.7662 - val_y2_output_loss: 4.3461 - val_y1_output_root_mean_squared_error: 0.8817 - val_y2_output_root_mean_squared_error: 2.0885
# Epoch 108/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.9014 - y1_output_loss: 0.6236 - y2_output_loss: 2.2787 - y1_output_root_mean_squared_error: 0.7883 - y2_output_root_mean_squared_error: 1.5099 - val_loss: 4.9474 - val_y1_output_loss: 0.8216 - val_y2_output_loss: 3.9696 - val_y1_output_root_mean_squared_error: 0.9165 - val_y2_output_root_mean_squared_error: 2.0267
# Epoch 109/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.5658 - y1_output_loss: 0.5821 - y2_output_loss: 1.9854 - y1_output_root_mean_squared_error: 0.7608 - y2_output_root_mean_squared_error: 1.4096 - val_loss: 9.8520 - val_y1_output_loss: 2.6324 - val_y2_output_loss: 6.9148 - val_y1_output_root_mean_squared_error: 1.6480 - val_y2_output_root_mean_squared_error: 2.6713
# Epoch 110/500
# 614/614 [==============================] - 0s 139us/sample - loss: 3.7473 - y1_output_loss: 0.8183 - y2_output_loss: 2.9054 - y1_output_root_mean_squared_error: 0.9080 - y2_output_root_mean_squared_error: 1.7096 - val_loss: 8.0592 - val_y1_output_loss: 2.2375 - val_y2_output_loss: 5.7856 - val_y1_output_root_mean_squared_error: 1.5044 - val_y2_output_root_mean_squared_error: 2.4075
# Epoch 111/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.1991 - y1_output_loss: 0.7789 - y2_output_loss: 2.4054 - y1_output_root_mean_squared_error: 0.8841 - y2_output_root_mean_squared_error: 1.5548 - val_loss: 2.5396 - val_y1_output_loss: 0.5879 - val_y2_output_loss: 1.9302 - val_y1_output_root_mean_squared_error: 0.7657 - val_y2_output_root_mean_squared_error: 1.3976
# Epoch 112/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.6023 - y1_output_loss: 0.5425 - y2_output_loss: 2.0489 - y1_output_root_mean_squared_error: 0.7393 - y2_output_root_mean_squared_error: 1.4338 - val_loss: 2.1614 - val_y1_output_loss: 0.3995 - val_y2_output_loss: 1.6871 - val_y1_output_root_mean_squared_error: 0.6403 - val_y2_output_root_mean_squared_error: 1.3234
# Epoch 113/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.3776 - y1_output_loss: 0.5894 - y2_output_loss: 1.7733 - y1_output_root_mean_squared_error: 0.7693 - y2_output_root_mean_squared_error: 1.3363 - val_loss: 2.1972 - val_y1_output_loss: 0.4080 - val_y2_output_loss: 1.7387 - val_y1_output_root_mean_squared_error: 0.6433 - val_y2_output_root_mean_squared_error: 1.3354
# Epoch 114/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.4708 - y1_output_loss: 0.5511 - y2_output_loss: 1.9109 - y1_output_root_mean_squared_error: 0.7379 - y2_output_root_mean_squared_error: 1.3879 - val_loss: 2.1628 - val_y1_output_loss: 0.4780 - val_y2_output_loss: 1.6471 - val_y1_output_root_mean_squared_error: 0.6989 - val_y2_output_root_mean_squared_error: 1.2939
# Epoch 115/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.3793 - y1_output_loss: 0.5419 - y2_output_loss: 1.8458 - y1_output_root_mean_squared_error: 0.7389 - y2_output_root_mean_squared_error: 1.3540 - val_loss: 3.6277 - val_y1_output_loss: 0.3902 - val_y2_output_loss: 3.2287 - val_y1_output_root_mean_squared_error: 0.6316 - val_y2_output_root_mean_squared_error: 1.7969
# Epoch 116/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.4045 - y1_output_loss: 0.6060 - y2_output_loss: 1.7856 - y1_output_root_mean_squared_error: 0.7786 - y2_output_root_mean_squared_error: 1.3410 - val_loss: 2.2533 - val_y1_output_loss: 0.6594 - val_y2_output_loss: 1.5369 - val_y1_output_root_mean_squared_error: 0.8193 - val_y2_output_root_mean_squared_error: 1.2578
# Epoch 117/500
# 614/614 [==============================] - 0s 147us/sample - loss: 2.9653 - y1_output_loss: 0.7571 - y2_output_loss: 2.1990 - y1_output_root_mean_squared_error: 0.8731 - y2_output_root_mean_squared_error: 1.4843 - val_loss: 2.6775 - val_y1_output_loss: 0.5262 - val_y2_output_loss: 2.1083 - val_y1_output_root_mean_squared_error: 0.7316 - val_y2_output_root_mean_squared_error: 1.4637
# Epoch 118/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.6100 - y1_output_loss: 0.5336 - y2_output_loss: 2.0678 - y1_output_root_mean_squared_error: 0.7305 - y2_output_root_mean_squared_error: 1.4410 - val_loss: 3.6371 - val_y1_output_loss: 0.7991 - val_y2_output_loss: 2.7098 - val_y1_output_root_mean_squared_error: 0.9090 - val_y2_output_root_mean_squared_error: 1.6765
# Epoch 119/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.4195 - y1_output_loss: 0.5179 - y2_output_loss: 1.9331 - y1_output_root_mean_squared_error: 0.7166 - y2_output_root_mean_squared_error: 1.3806 - val_loss: 2.2577 - val_y1_output_loss: 0.4390 - val_y2_output_loss: 1.7797 - val_y1_output_root_mean_squared_error: 0.6685 - val_y2_output_root_mean_squared_error: 1.3456
# Epoch 120/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.7687 - y1_output_loss: 0.6370 - y2_output_loss: 2.1230 - y1_output_root_mean_squared_error: 0.7979 - y2_output_root_mean_squared_error: 1.4601 - val_loss: 3.5901 - val_y1_output_loss: 0.8915 - val_y2_output_loss: 2.5966 - val_y1_output_root_mean_squared_error: 0.9521 - val_y2_output_root_mean_squared_error: 1.6382
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.4372 - y1_output_loss: 0.1228 - y2_output_loss: 0.3111 - y1_output_root_mean_squared_error: 0.3515 - y2_output_root_mean_squared_error: 0.5600 - val_loss: 0.8729 - val_y1_output_loss: 0.1958 - val_y2_output_loss: 0.6564 - val_y1_output_root_mean_squared_error: 0.4473 - val_y2_output_root_mean_squared_error: 0.8203
# Epoch 462/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3995 - y1_output_loss: 0.1139 - y2_output_loss: 0.2865 - y1_output_root_mean_squared_error: 0.3390 - y2_output_root_mean_squared_error: 0.5335 - val_loss: 2.2108 - val_y1_output_loss: 0.3563 - val_y2_output_loss: 1.8649 - val_y1_output_root_mean_squared_error: 0.6008 - val_y2_output_root_mean_squared_error: 1.3601
# Epoch 463/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.4639 - y1_output_loss: 0.1113 - y2_output_loss: 0.3486 - y1_output_root_mean_squared_error: 0.3347 - y2_output_root_mean_squared_error: 0.5932 - val_loss: 0.8153 - val_y1_output_loss: 0.1579 - val_y2_output_loss: 0.6490 - val_y1_output_root_mean_squared_error: 0.4012 - val_y2_output_root_mean_squared_error: 0.8089
# Epoch 464/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3682 - y1_output_loss: 0.1145 - y2_output_loss: 0.2598 - y1_output_root_mean_squared_error: 0.3388 - y2_output_root_mean_squared_error: 0.5034 - val_loss: 2.0472 - val_y1_output_loss: 0.2047 - val_y2_output_loss: 1.7878 - val_y1_output_root_mean_squared_error: 0.4578 - val_y2_output_root_mean_squared_error: 1.3556
# Epoch 465/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4418 - y1_output_loss: 0.1255 - y2_output_loss: 0.3150 - y1_output_root_mean_squared_error: 0.3539 - y2_output_root_mean_squared_error: 0.5627 - val_loss: 1.1337 - val_y1_output_loss: 0.3031 - val_y2_output_loss: 0.8163 - val_y1_output_root_mean_squared_error: 0.5546 - val_y2_output_root_mean_squared_error: 0.9089
# Epoch 466/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4184 - y1_output_loss: 0.1297 - y2_output_loss: 0.2885 - y1_output_root_mean_squared_error: 0.3610 - y2_output_root_mean_squared_error: 0.5367 - val_loss: 0.9239 - val_y1_output_loss: 0.1981 - val_y2_output_loss: 0.7108 - val_y1_output_root_mean_squared_error: 0.4457 - val_y2_output_root_mean_squared_error: 0.8516
# Epoch 467/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4984 - y1_output_loss: 0.1521 - y2_output_loss: 0.3450 - y1_output_root_mean_squared_error: 0.3909 - y2_output_root_mean_squared_error: 0.5878 - val_loss: 1.2784 - val_y1_output_loss: 0.2383 - val_y2_output_loss: 1.0480 - val_y1_output_root_mean_squared_error: 0.4894 - val_y2_output_root_mean_squared_error: 1.0193
# Epoch 468/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.5027 - y1_output_loss: 0.1332 - y2_output_loss: 0.3657 - y1_output_root_mean_squared_error: 0.3658 - y2_output_root_mean_squared_error: 0.6073 - val_loss: 0.9331 - val_y1_output_loss: 0.1868 - val_y2_output_loss: 0.7156 - val_y1_output_root_mean_squared_error: 0.4366 - val_y2_output_root_mean_squared_error: 0.8617
# Epoch 469/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4672 - y1_output_loss: 0.1268 - y2_output_loss: 0.3394 - y1_output_root_mean_squared_error: 0.3572 - y2_output_root_mean_squared_error: 0.5827 - val_loss: 1.2280 - val_y1_output_loss: 0.2265 - val_y2_output_loss: 0.9753 - val_y1_output_root_mean_squared_error: 0.4791 - val_y2_output_root_mean_squared_error: 0.9992
# Epoch 470/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3741 - y1_output_loss: 0.1050 - y2_output_loss: 0.2675 - y1_output_root_mean_squared_error: 0.3240 - y2_output_root_mean_squared_error: 0.5188 - val_loss: 0.8038 - val_y1_output_loss: 0.1687 - val_y2_output_loss: 0.6342 - val_y1_output_root_mean_squared_error: 0.4113 - val_y2_output_root_mean_squared_error: 0.7966
# Epoch 471/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3646 - y1_output_loss: 0.1126 - y2_output_loss: 0.2494 - y1_output_root_mean_squared_error: 0.3362 - y2_output_root_mean_squared_error: 0.5016 - val_loss: 0.7793 - val_y1_output_loss: 0.1609 - val_y2_output_loss: 0.6094 - val_y1_output_root_mean_squared_error: 0.4025 - val_y2_output_root_mean_squared_error: 0.7857
# Epoch 472/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.4138 - y1_output_loss: 0.1272 - y2_output_loss: 0.2841 - y1_output_root_mean_squared_error: 0.3582 - y2_output_root_mean_squared_error: 0.5343 - val_loss: 0.8458 - val_y1_output_loss: 0.1826 - val_y2_output_loss: 0.6394 - val_y1_output_root_mean_squared_error: 0.4312 - val_y2_output_root_mean_squared_error: 0.8123
# Epoch 473/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4871 - y1_output_loss: 0.1319 - y2_output_loss: 0.3553 - y1_output_root_mean_squared_error: 0.3624 - y2_output_root_mean_squared_error: 0.5965 - val_loss: 0.8708 - val_y1_output_loss: 0.1854 - val_y2_output_loss: 0.6615 - val_y1_output_root_mean_squared_error: 0.4334 - val_y2_output_root_mean_squared_error: 0.8264
# Epoch 474/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.4477 - y1_output_loss: 0.1247 - y2_output_loss: 0.3200 - y1_output_root_mean_squared_error: 0.3536 - y2_output_root_mean_squared_error: 0.5681 - val_loss: 0.9531 - val_y1_output_loss: 0.2042 - val_y2_output_loss: 0.7320 - val_y1_output_root_mean_squared_error: 0.4536 - val_y2_output_root_mean_squared_error: 0.8645
# Epoch 475/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3564 - y1_output_loss: 0.1215 - y2_output_loss: 0.2456 - y1_output_root_mean_squared_error: 0.3436 - y2_output_root_mean_squared_error: 0.4882 - val_loss: 4.0270 - val_y1_output_loss: 0.8709 - val_y2_output_loss: 3.0361 - val_y1_output_root_mean_squared_error: 0.9489 - val_y2_output_root_mean_squared_error: 1.7682
# Epoch 476/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.6046 - y1_output_loss: 0.1734 - y2_output_loss: 0.4262 - y1_output_root_mean_squared_error: 0.4179 - y2_output_root_mean_squared_error: 0.6557 - val_loss: 0.7901 - val_y1_output_loss: 0.1552 - val_y2_output_loss: 0.6163 - val_y1_output_root_mean_squared_error: 0.3991 - val_y2_output_root_mean_squared_error: 0.7942
# Epoch 477/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3995 - y1_output_loss: 0.1018 - y2_output_loss: 0.2948 - y1_output_root_mean_squared_error: 0.3204 - y2_output_root_mean_squared_error: 0.5448 - val_loss: 0.9376 - val_y1_output_loss: 0.1754 - val_y2_output_loss: 0.7333 - val_y1_output_root_mean_squared_error: 0.4242 - val_y2_output_root_mean_squared_error: 0.8704
# Epoch 478/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4241 - y1_output_loss: 0.1217 - y2_output_loss: 0.3039 - y1_output_root_mean_squared_error: 0.3465 - y2_output_root_mean_squared_error: 0.5514 - val_loss: 1.1081 - val_y1_output_loss: 0.3147 - val_y2_output_loss: 0.7737 - val_y1_output_root_mean_squared_error: 0.5643 - val_y2_output_root_mean_squared_error: 0.8886
# Epoch 479/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3908 - y1_output_loss: 0.1140 - y2_output_loss: 0.2748 - y1_output_root_mean_squared_error: 0.3383 - y2_output_root_mean_squared_error: 0.5257 - val_loss: 0.7976 - val_y1_output_loss: 0.1852 - val_y2_output_loss: 0.5909 - val_y1_output_root_mean_squared_error: 0.4341 - val_y2_output_root_mean_squared_error: 0.7805
# Epoch 480/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3535 - y1_output_loss: 0.1094 - y2_output_loss: 0.2427 - y1_output_root_mean_squared_error: 0.3313 - y2_output_root_mean_squared_error: 0.4937 - val_loss: 0.8544 - val_y1_output_loss: 0.2032 - val_y2_output_loss: 0.6311 - val_y1_output_root_mean_squared_error: 0.4513 - val_y2_output_root_mean_squared_error: 0.8067
# Epoch 481/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4259 - y1_output_loss: 0.1157 - y2_output_loss: 0.3077 - y1_output_root_mean_squared_error: 0.3407 - y2_output_root_mean_squared_error: 0.5566 - val_loss: 0.8985 - val_y1_output_loss: 0.1550 - val_y2_output_loss: 0.7152 - val_y1_output_root_mean_squared_error: 0.3984 - val_y2_output_root_mean_squared_error: 0.8601
# Epoch 482/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4962 - y1_output_loss: 0.1149 - y2_output_loss: 0.3789 - y1_output_root_mean_squared_error: 0.3398 - y2_output_root_mean_squared_error: 0.6171 - val_loss: 0.8904 - val_y1_output_loss: 0.1704 - val_y2_output_loss: 0.6960 - val_y1_output_root_mean_squared_error: 0.4160 - val_y2_output_root_mean_squared_error: 0.8469
# Epoch 483/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4606 - y1_output_loss: 0.1277 - y2_output_loss: 0.3290 - y1_output_root_mean_squared_error: 0.3588 - y2_output_root_mean_squared_error: 0.5760 - val_loss: 0.8479 - val_y1_output_loss: 0.1664 - val_y2_output_loss: 0.6540 - val_y1_output_root_mean_squared_error: 0.4132 - val_y2_output_root_mean_squared_error: 0.8229
# Epoch 484/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.4690 - y1_output_loss: 0.1380 - y2_output_loss: 0.3343 - y1_output_root_mean_squared_error: 0.3719 - y2_output_root_mean_squared_error: 0.5750 - val_loss: 1.2338 - val_y1_output_loss: 0.2256 - val_y2_output_loss: 0.9665 - val_y1_output_root_mean_squared_error: 0.4820 - val_y2_output_root_mean_squared_error: 1.0007
# Epoch 485/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4733 - y1_output_loss: 0.1487 - y2_output_loss: 0.3206 - y1_output_root_mean_squared_error: 0.3873 - y2_output_root_mean_squared_error: 0.5686 - val_loss: 0.8683 - val_y1_output_loss: 0.1553 - val_y2_output_loss: 0.6876 - val_y1_output_root_mean_squared_error: 0.3974 - val_y2_output_root_mean_squared_error: 0.8428
# Epoch 486/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3020 - y1_output_loss: 0.1021 - y2_output_loss: 0.2104 - y1_output_root_mean_squared_error: 0.3155 - y2_output_root_mean_squared_error: 0.4500 - val_loss: 1.6915 - val_y1_output_loss: 0.5806 - val_y2_output_loss: 1.0538 - val_y1_output_root_mean_squared_error: 0.7754 - val_y2_output_root_mean_squared_error: 1.0442
# Epoch 487/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4304 - y1_output_loss: 0.1354 - y2_output_loss: 0.2959 - y1_output_root_mean_squared_error: 0.3667 - y2_output_root_mean_squared_error: 0.5440 - val_loss: 1.0685 - val_y1_output_loss: 0.3674 - val_y2_output_loss: 0.6678 - val_y1_output_root_mean_squared_error: 0.6136 - val_y2_output_root_mean_squared_error: 0.8318
# Epoch 488/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4509 - y1_output_loss: 0.1389 - y2_output_loss: 0.3160 - y1_output_root_mean_squared_error: 0.3698 - y2_output_root_mean_squared_error: 0.5605 - val_loss: 2.0131 - val_y1_output_loss: 0.4829 - val_y2_output_loss: 1.5281 - val_y1_output_root_mean_squared_error: 0.6984 - val_y2_output_root_mean_squared_error: 1.2350
# Epoch 489/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3872 - y1_output_loss: 0.1177 - y2_output_loss: 0.2663 - y1_output_root_mean_squared_error: 0.3445 - y2_output_root_mean_squared_error: 0.5182 - val_loss: 0.8746 - val_y1_output_loss: 0.1859 - val_y2_output_loss: 0.6679 - val_y1_output_root_mean_squared_error: 0.4339 - val_y2_output_root_mean_squared_error: 0.8285
# Epoch 490/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3983 - y1_output_loss: 0.1119 - y2_output_loss: 0.2861 - y1_output_root_mean_squared_error: 0.3356 - y2_output_root_mean_squared_error: 0.5345 - val_loss: 0.8456 - val_y1_output_loss: 0.1683 - val_y2_output_loss: 0.6545 - val_y1_output_root_mean_squared_error: 0.4146 - val_y2_output_root_mean_squared_error: 0.8208
# Epoch 491/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.5491 - y1_output_loss: 0.1532 - y2_output_loss: 0.3935 - y1_output_root_mean_squared_error: 0.3907 - y2_output_root_mean_squared_error: 0.6297 - val_loss: 1.3296 - val_y1_output_loss: 0.3969 - val_y2_output_loss: 0.8855 - val_y1_output_root_mean_squared_error: 0.6413 - val_y2_output_root_mean_squared_error: 0.9583
# Epoch 492/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3713 - y1_output_loss: 0.1135 - y2_output_loss: 0.2572 - y1_output_root_mean_squared_error: 0.3364 - y2_output_root_mean_squared_error: 0.5081 - val_loss: 0.8806 - val_y1_output_loss: 0.2084 - val_y2_output_loss: 0.6446 - val_y1_output_root_mean_squared_error: 0.4610 - val_y2_output_root_mean_squared_error: 0.8173
# Epoch 493/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3443 - y1_output_loss: 0.1129 - y2_output_loss: 0.2293 - y1_output_root_mean_squared_error: 0.3365 - y2_output_root_mean_squared_error: 0.4807 - val_loss: 0.8222 - val_y1_output_loss: 0.1669 - val_y2_output_loss: 0.6399 - val_y1_output_root_mean_squared_error: 0.4126 - val_y2_output_root_mean_squared_error: 0.8075
# Epoch 494/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3346 - y1_output_loss: 0.1040 - y2_output_loss: 0.2311 - y1_output_root_mean_squared_error: 0.3228 - y2_output_root_mean_squared_error: 0.4799 - val_loss: 1.0104 - val_y1_output_loss: 0.1613 - val_y2_output_loss: 0.8156 - val_y1_output_root_mean_squared_error: 0.4080 - val_y2_output_root_mean_squared_error: 0.9187
# Epoch 495/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3296 - y1_output_loss: 0.1062 - y2_output_loss: 0.2208 - y1_output_root_mean_squared_error: 0.3267 - y2_output_root_mean_squared_error: 0.4721 - val_loss: 0.8715 - val_y1_output_loss: 0.2118 - val_y2_output_loss: 0.6446 - val_y1_output_root_mean_squared_error: 0.4643 - val_y2_output_root_mean_squared_error: 0.8099
# Epoch 496/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.4077 - y1_output_loss: 0.1137 - y2_output_loss: 0.2969 - y1_output_root_mean_squared_error: 0.3379 - y2_output_root_mean_squared_error: 0.5418 - val_loss: 1.5005 - val_y1_output_loss: 0.2572 - val_y2_output_loss: 1.2139 - val_y1_output_root_mean_squared_error: 0.5067 - val_y2_output_root_mean_squared_error: 1.1152
# Epoch 497/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.6487 - y1_output_loss: 0.1584 - y2_output_loss: 0.4858 - y1_output_root_mean_squared_error: 0.3993 - y2_output_root_mean_squared_error: 0.6995 - val_loss: 0.7756 - val_y1_output_loss: 0.1486 - val_y2_output_loss: 0.6111 - val_y1_output_root_mean_squared_error: 0.3917 - val_y2_output_root_mean_squared_error: 0.7888
# Epoch 498/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3204 - y1_output_loss: 0.1096 - y2_output_loss: 0.2237 - y1_output_root_mean_squared_error: 0.3267 - y2_output_root_mean_squared_error: 0.4622 - val_loss: 2.7264 - val_y1_output_loss: 0.4571 - val_y2_output_loss: 2.2561 - val_y1_output_root_mean_squared_error: 0.6782 - val_y2_output_root_mean_squared_error: 1.5055
# Epoch 499/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4837 - y1_output_loss: 0.1375 - y2_output_loss: 0.3509 - y1_output_root_mean_squared_error: 0.3686 - y2_output_root_mean_squared_error: 0.5898 - val_loss: 1.6477 - val_y1_output_loss: 0.2281 - val_y2_output_loss: 1.3704 - val_y1_output_root_mean_squared_error: 0.4845 - val_y2_output_root_mean_squared_error: 1.1887
# Epoch 500/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.7098 - y1_output_loss: 0.1582 - y2_output_loss: 0.5456 - y1_output_root_mean_squared_error: 0.3988 - y2_output_root_mean_squared_error: 0.7421 - val_loss: 0.8435 - val_y1_output_loss: 0.1523 - val_y2_output_loss: 0.6654 - val_y1_output_root_mean_squared_error: 0.3961 - val_y2_output_root_mean_squared_error: 0.8286

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 32us/sample - loss: 0.8435 - y1_output_loss: 0.1590 - y2_output_loss: 0.6879 - y1_output_root_mean_squared_error: 0.3961 - y2_output_root_mean_squared_error: 0.8286
# Loss = 0.8435028435347917, Y1_loss = 0.15900766849517822, Y1_mse = 0.39608222246170044, Y2_loss = 0.687913179397583, Y2_mse = 0.8286263942718506

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
